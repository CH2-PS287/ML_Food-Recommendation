# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('One_instance_Porsi.csv')
x = data.drop('name', axis=1)
porsi= x['Porsi']
x = x.drop('Porsi', axis=1)
y = data['name']

# %%
data
# Out:
#                  name    Air  Energi  Protein  Lemak    Abu  Karbohidrat  \
# 0       Ayam Cabe Ijo  58181    1554       50   2369  21513        32437
# 1       Chicken Katsu  68966    3386     9881  21828  18301        29912
# 2         Ayam Penyet  68023    2586     9623  17257  22002        23163
# 3    Egg Chicken Roll  49498    2667     4211  22092  20573        13626
# 4   Ayam Saus Inggris  57585    2436     4797  12335  12301        32482
# ..                ...    ...     ...      ...    ...    ...          ...
# 57   Kangkung Belacan  41306    1909     2446  10985   1588        23678
# 58       Sate Taichan  61045    1580     7167   2424  26286        32005
# 59       Sate Kambing  80579    1231     8996   3368   5493        21022
# 60           Nagasari   7941    1753      674   1016    101        21126
# 61             Bakpao   7253    3060     8175   9477  21332        48663
#
#     Serat Total  Gula Total  Kalsium (Ca)  ...  Zeaksantin + Lutein  \
# ...

# %%
x = x.div(porsi,axis=0).round(2)

# %%
data=pd.concat([y,x],axis=1)

# %%
data
# Out:
#                  name       Air  Energi  Protein    Lemak      Abu  \
# 0       Ayam Cabe Ijo    909.08   24.28     0.78    37.02   336.14
# 1       Chicken Katsu  17241.50  846.50  2470.25  5457.00  4575.25
# 2         Ayam Penyet  17005.75  646.50  2405.75  4314.25  5500.50
# 3    Egg Chicken Roll   3093.62  166.69   263.19  1380.75  1285.81
# 4   Ayam Saus Inggris   3599.06  152.25   299.81   770.94   768.81
# ..                ...       ...     ...      ...      ...      ...
# 57   Kangkung Belacan  10326.50  477.25   611.50  2746.25   397.00
# 58       Sate Taichan   3815.31   98.75   447.94   151.50  1642.88
# 59       Sate Kambing    201.45    3.08    22.49     8.42    13.73
# 60           Nagasari     12.71    2.80     1.08     1.63     0.16
# 61             Bakpao     50.37   21.25    56.77    65.81   148.14
#
#     Karbohidrat  Serat Total  Gula Total  Kalsium (Ca)  ...  Likopen  \
# 0        506.83         7.22      184.98         14.53  ...     0.31
# ...
