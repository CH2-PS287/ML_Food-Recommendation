# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf

# %%
# Read dataset csv
lauk = pd.read_csv(r'Dataset\Augmented Data\augmented_lauk_with_nutrition.csv')
minum_snack = pd.read_csv(r'Dataset\Augmented Data\augmented_minum_snack_with_nutrition.csv')
minum_nutrisi = pd.read_csv(r'Dataset\Augmented Data\augmented_minum_with_nutrition.csv')
pokok_lauk = pd.read_csv(r'Dataset\Augmented Data\augmented_pokok_lauk_with_nutrition.csv')
sayur = pd.read_csv(r'Dataset\Augmented Data\augmented_sayur_with_nutrition.csv')
snack_lauk = pd.read_csv(r'Dataset\Augmented Data\augmented_snack_lauk_with_nutrition.csv')
snack_nutri = pd.read_csv(r'Dataset\Augmented Data\augmented_snack_with_nutrition.csv')
Dataset=pd.concat([lauk,minum_snack,minum_nutrisi,pokok_lauk,sayur,snack_lauk,snack_nutri],ignore_index=True)
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', 10)
Dataset.head(10)
# Out:
#             name     Air   Energi Protein  Lemak     Abu Karbohidrat  \
# 0  Ayam Cabe Ijo  581,81     1554      50  23,69  215,13      324,37
# 1  Ayam Cabe Ijo  582,08  1554,49   49,29  23,76  215,68       325,0
# 2  Ayam Cabe Ijo  580,93   1553,8   49,55   24,2  215,38      325,15
# 3  Ayam Cabe Ijo  581,04  1554,26   49,55  23,23   215,5      323,84
# 4  Ayam Cabe Ijo  581,89  1553,99   49,86  24,12  215,53      324,09
# 5  Ayam Cabe Ijo  581,16  1553,75   50,14  23,35  214,58      324,66
# 6  Ayam Cabe Ijo  581,05  1554,91   50,67  23,32  215,44      324,18
# 7  Ayam Cabe Ijo  580,92  1554,48   49,62   24,5  215,51      324,92
# 8  Ayam Cabe Ijo  582,69  1553,03   49,39  23,31  215,65      325,33
# 9  Ayam Cabe Ijo   582,2  1553,62   49,89  24,06  214,54       324,9
#
#   Serat Total Gula Total Kalsium (Ca) Besi (Fe) Magnesium (Mg) Fosfor (P)  \
# 0        46,2     118,39          930      43,2            532        831
# ...

# %%
lauk.columns
# Out:
# Index(['name', 'Air', 'Energi', 'Protein', 'Lemak', 'Abu', 'Karbohidrat',
#        'Serat Total', 'Gula Total', 'Kalsium (Ca)', 'Besi (Fe)',
#        'Magnesium (Mg)', 'Fosfor (P)', 'Kalium (K)', 'Natrium (Na)',
#        'Seng (Zn)', 'Tembaga (Cu)', 'Mangan (Mn)', 'Selenium (Se)',
#        'Vitamin C', 'Tiamina (B1)', 'Riboflavin (B2)', 'Niasin',
#        'Pantotenat (B5)', 'Vitamin B6', 'Folat Total (B9)', 'Kolina',
#        'Vitamin B12', 'Vitamin A IU', 'Vitamin A RAE', 'Retinol', 'a-karoten',
#        'b-karoten', 'b-kriptosantin', 'Likopen', 'Zeaksantin + Lutein',
#        'Vitamin E', 'Vitamin D', 'Vitamin D IU', 'Vitamin K', 'Lemak Jenuh',
#        'Lemak Tunggal', 'Lemak Ganda', 'Kolesterol'],
#       dtype='object')

# %%
Dataset.replace({',': ''}, regex=True, inplace=True)
Dataset = Dataset.apply(pd.to_numeric, errors='ignore')
Dataset.describe()
# Out:
#                  Air         Energi       Protein         Lemak           Abu  \
# count     620.000000     620.000000    620.000000    620.000000    620.000000
# mean    45583.396774  204127.170968   6028.603226  11676.904839  13677.753226
# std     24504.874287  147265.688286   4035.421359   9436.567726   8956.037047
# min        86.000000     -89.000000    -95.000000    -97.000000    -86.000000
# 25%     34352.500000   44955.500000   2776.000000   2401.750000   7169.500000
# 50%     45767.500000  200005.500000   5697.500000  10707.000000  12477.500000
# 75%     61108.000000  304321.250000   8263.750000  19327.500000  21329.000000
# max    104005.000000  591486.000000  18202.000000  37446.000000  33296.000000
#
#          Karbohidrat   Serat Total    Gula Total  Kalsium (Ca)     Besi (Fe)  \
# count     620.000000    620.000000    620.000000  6.200000e+02    620.000000
# mean    28782.520968   4913.883871   7764.083871  1.256500e+05   4596.737097
# ...

# %%
features = Dataset.drop(['name'],axis=1)
labels = Dataset['name']
label_encoder = LabelEncoder()
labels_encoded = pd.Series(label_encoder.fit_transform(labels))
X_train, X_test, y_train, y_test = train_test_split(features, labels_encoded, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(scaler.transform(X_test),columns=X_test.columns, index=X_test.index)
X_train_scaled
# Out:
#           Air    Energi   Protein     Lemak       Abu  Karbohidrat  \
# 531  2.185455  1.746465  2.663117  0.815510  1.766406     1.932085
# 364 -1.681998 -0.209266  0.178357 -0.665910 -0.114963     0.307892
# 177  0.236055  0.522250  0.814844 -0.620851 -0.037183    -1.204658
# 595 -1.518257 -0.563898  0.759129 -0.897918 -0.904233    -0.412220
# 199  0.660224  0.239330 -0.330782  0.037889 -1.408043     0.088021
# ..        ...       ...       ...       ...       ...          ...
# 71   0.480546  0.718342  0.764601 -0.393530  1.582686     1.542489
# 106  0.307633  1.699010  0.643970 -0.965667 -1.390444     1.051656
# 270 -0.044957 -1.411207 -0.367345 -1.030007 -0.288918    -0.033399
# 435  1.234560  0.085818 -0.547173 -0.109432 -0.214885    -0.024832
# 102  0.310283  1.699469  0.649939  1.568630 -0.101906    -1.260322
#
#      Serat Total  Gula Total  Kalsium (Ca)  Besi (Fe)  Magnesium (Mg)  \
# 531    -0.591721    0.375997      0.488722   2.397572        2.307005
# ...

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train_scaled, y_train))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_scaled, y_test))
train_dataset
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(43,), dtype=tf.float64, name=None), TensorSpec(shape=(), dtype=tf.int32, name=None))>
